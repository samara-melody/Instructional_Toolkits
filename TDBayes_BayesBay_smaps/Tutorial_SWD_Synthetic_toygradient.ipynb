# %% [markdown]
# ### Tutorial — BayesBay Workbook: Rayleigh Wave Dispersion
#
# This notebook generates synthetic Rayleigh wave dispersion data (using **disba**) and performs a transdimensional (TD) Bayesian inversion (using **BayesBay**) to solve for a 1-D shear-wave velocity profile.
#
# To keep the workflow simple and focused on learning the core concepts of TD Bayes with BayesBay, supplemental functions are stored in external `.py` files:
#
# - **`smo_plotting_swd.py`** — Plotting functions for models, data, and solutions (some call BayesBay utilities).
# - **`smo_models.py`** — Example Earth models and code to format them for **disba**.
#
# The notebook follows a more linear, step-by-step structure than the standard BayesBay tutorials, with all key user-defined variables grouped in one cell, followed by sequential implementation steps:
#
# 1. **Import packages**
# 2. **Create synthetic data** (and optionally explore sensitivities)
# 3. **Set user-defined variables** and prepare frameworks for TD Bayes implementation
# 4. **Run inversion**
# 5. **Plot results**

# %%
###################
# IMPORT PACKAGES #
###################

import bayesbay as bb
from bayesbay.discretization import Voronoi1D
from bayesbay.likelihood import Target
from bayesbay.likelihood import LogLikelihood

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm

import importlib
import smo_plotting_swd as sf
import smo_models as models

from disba import PhaseDispersion
np.random.seed(30)

# %%
importlib.reload(models)
importlib.reload(sf)

##########################
# CREATE SYNTHETIC MODEL #
##########################
thick, vp, vs, rho = models.toy_gradient()
THICK, VP, VS, RHO = models.generate(thick, vp, vs, rho) ## discretizes model into 1-m-thick layers

# Velocity model in format of: thickness, Vp, Vs, density (km, km/s, km/s, g/cm3)
velocity_model = np.column_stack((THICK/1000, VP/1000, VS/1000, RHO/1000))[::-1]
depths = np.cumsum(velocity_model[:,0])

fig, ax = sf.plot_synthetic_model(velocity_model, depths)

########################
# CREATE OBSERVED DATA #
########################

# Periods must be sorted starting with low periods
minfreq = 2
maxfreq = 60
periods = np.geomspace(1/maxfreq, 1/minfreq, 30)   
periods = np.linspace(1/maxfreq, 1/minfreq, 30)   

pd = PhaseDispersion(*velocity_model.T)
f_true = 1/periods
d_true = pd(periods, mode=0, wave="rayleigh").velocity

# add some noise to the true SWD data
noise_std_true = 0.001
d_obs = d_true + np.random.normal(0, noise_std_true, d_true.size)

# ignore ultra-low frequencies (assuming we cannot record these)
d_obs = d_obs[:]
f_obs = f_true[:]

fig, ax = sf.plot_observed_data(f_obs, d_obs, f_true, d_true)


################################
# EXPLORING DATA SENSITIVITIES #
################################
from disba import EigenFunction
eigf = EigenFunction(*velocity_model.T)

fig, ax = sf.plot_rayleigh_eigenfunctions(velocity_model, thick, np.unique(f_obs.astype(int)))

# %%
importlib.reload(sf)

### 01 VORONOI POSITIONS
vmin=0
vmax=.50
perturb_std=.001

### 02 VELOCITY MODEL SPACE
# Define upper and lower bounds i.e. vmax and vmin
vs_min=np.array([1.0, 1.2, 1.4, 1.5])
vs_max=np.array([1.8, 2.2, 2.5, 2.8])
# Define control points (position in discretization domain) for defining a depth-dependent Vs prior
vs_position=np.array([0, .10, .20, .30])
# Define standard deviation of the Gaussians used to randomly perturb the parameter i.e. perturb_std
vs_perturb_std=.001

### 03 TD PARAMETERS
n_dimensions=None
n_dimensions_min=3  # ignored if n_dimensions is defined 
n_dimensions_max=5 # ignored if n_dimensions is defined

### 04 NOISE
std_min=0.0001
std_max=0.003
std_perturb_std=0.0005

### 05 FORWARD MODELER
vp_vs = 2
def forward_vp(vs, vpvs=vp_vs):
    return vs * vpvs
def forward_rho(vs, vpvs=vp_vs):
    return 1.74 * ((vs * vpvs)**.25)

def forward_sw(state):
    voronoi = state["voronoi"]
    voronoi_sites = voronoi["discretization"]
    thickness = Voronoi1D.compute_cell_extents(voronoi_sites)
    vs = voronoi["vs"]
    
    vp = forward_vp(vs)
    rho = forward_rho(vs)
    pd = PhaseDispersion(thickness, vp, vs, rho)
    d_pred = pd(1/f_obs, mode=0, wave="rayleigh").velocity
    return d_pred

### 06 MCMC PARAMETERS
n_chains=12
n_iterations=250_000
burnin_iterations=100_000
save_every=100



####################################################################################################
# DEFINE INITIAL MODEL and PRIORS for VS and DEPTH #
####################################################################################################
def initialize_vs(param, positions=vs_position):
    vmin, vmax = param.get_vmin_vmax(positions)
    sorted_vals = np.sort(np.random.uniform(vmin, vmax, positions.size))
    return sorted_vals

# A uniform Vs prior
vs = bb.prior.UniformPrior(name="vs", vmin=vs_min, vmax=vs_max, position=vs_position, perturb_std=vs_perturb_std)
start = initialize_vs
vs.set_custom_initialize(initialize_vs)

# Plot prior
depth_prior = np.linspace(0, max(vs_position))  
vmin_prior, vmax_prior = vs.get_vmin_vmax(depth_prior) # get bounds for every depth in depth prior

sf.plot_parameters(forward_vp, forward_rho,
    vmin, vmax, perturb_std, std_min, std_max, std_perturb_std,
    n_dimensions, n_dimensions_min, n_dimensions_max,
    vs_min, vs_max, vs_position, vs_perturb_std, vp_vs,
    n_chains, n_iterations, burnin_iterations, save_every,
    vmin_prior, vmax_prior, depth_prior, Voronoi1D, velocity_model, depths)


####################################################################################################
# BUILD DISCRETIZED SPACE 
# i.e. parameters for each nuclei, and rules for how it can be manipulated #
####################################################################################################
voronoi = Voronoi1D(name="voronoi", vmin=vmin,vmax=vmax, perturb_std=perturb_std,      
    n_dimensions=n_dimensions, n_dimensions_min=n_dimensions_min, n_dimensions_max=n_dimensions_max,
    parameters=[vs], birth_from='neighbour')
    # can initialize the free parameters associated with the newborn Voronoi cell by 
    # randomly drawing from their prior or by perturbing the value found in the nearest Voronoi cell (default).
parameterization = bb.parameterization.Parameterization(voronoi)


####################################################################################################
# BUILD FRAMEWORK for LOGLIKELIHOOD 
# i.e. the forward modeling of calculated data and how it is compared to observed TARGET data #
####################################################################################################
target = Target("rayleigh", d_obs, std_min=std_min, std_max=std_max, std_perturb_std=std_perturb_std)
log_likelihood = LogLikelihood(targets=target, fwd_functions=forward_sw)

# %%
import time
start = time.time()
##################################################################################################
# INVERSION SET UP AND RAN based on FREE PARAMETERS, LOGLIKELIHOOD FRAMEWORK and MCMC PARAMETERS #
##################################################################################################
inversion = bb.BayesianInversion(parameterization=parameterization, log_likelihood=log_likelihood,n_chains=n_chains)
inversion.run(sampler=None, n_iterations=n_iterations, burnin_iterations=burnin_iterations, save_every=save_every, verbose=False)

for chain in inversion.chains:
    chain.print_statistics()
    
##################################################################################################
end = time.time()
print(f"Elapsed time: {(end - start)/60:.4f} minutes")
# Out:
# Chain ID: 0
# TEMPERATURE: 1
# EXPLORED MODELS: 250000
# ACCEPTANCE RATE: 111332/250000 (44.53 %)
# PARTIAL ACCEPTANCE RATES:
# 	NoisePerturbation(rayleigh): 14746/35856 (41.13%)
# 	ParamSpacePerturbation(param_space_name=voronoi):
# 		BirthPerturbation(voronoi): 7.00/35588.00 (0.02%)
# 		DeathPerturbation(voronoi): 5.00/35852.00 (0.01%)
# 		ParamPerturbation(voronoi.discretization): 20844.00/35368.00 (58.93%)
# 		ParamPerturbation(voronoi.vs): 75730.00/107336.00 (70.55%)
# Chain ID: 1
# TEMPERATURE: 1
# EXPLORED MODELS: 250000
# ACCEPTANCE RATE: 110517/250000 (44.21 %)
# PARTIAL ACCEPTANCE RATES:
# 	NoisePerturbation(rayleigh): 15839/35780 (44.27%)
# 	ParamSpacePerturbation(param_space_name=voronoi):
# 		BirthPerturbation(voronoi): 86.00/35823.00 (0.24%)
# 		DeathPerturbation(voronoi): 85.00/35707.00 (0.24%)
# 		ParamPerturbation(voronoi.discretization): 21450.00/35772.00 (59.96%)
# 		ParamPerturbation(voronoi.vs): 73057.00/106918.00 (68.33%)
# Chain ID: 2
# TEMPERATURE: 1
# EXPLORED MODELS: 250000
# ACCEPTANCE RATE: 121973/250000 (48.79 %)
# PARTIAL ACCEPTANCE RATES:
# 	NoisePerturbation(rayleigh): 17829/35665 (49.99%)
# 	ParamSpacePerturbation(param_space_name=voronoi):
# 		BirthPerturbation(voronoi): 202.00/35744.00 (0.57%)
# 		DeathPerturbation(voronoi): 201.00/35765.00 (0.56%)
# 		ParamPerturbation(voronoi.discretization): 22971.00/35695.00 (64.35%)
# 		ParamPerturbation(voronoi.vs): 80770.00/107131.00 (75.39%)
# Chain ID: 3
# TEMPERATURE: 1
# EXPLORED MODELS: 250000
# ACCEPTANCE RATE: 131783/250000 (52.71 %)
# PARTIAL ACCEPTANCE RATES:
# 	NoisePerturbation(rayleigh): 20220/35830 (56.43%)
# 	ParamSpacePerturbation(param_space_name=voronoi):
# 		BirthPerturbation(voronoi): 11.00/35810.00 (0.03%)
# 		DeathPerturbation(voronoi): 9.00/35527.00 (0.03%)
# 		ParamPerturbation(voronoi.discretization): 25834.00/35694.00 (72.38%)
# 		ParamPerturbation(voronoi.vs): 85709.00/107139.00 (80.00%)
# Chain ID: 4
# TEMPERATURE: 1
# EXPLORED MODELS: 250000
# ACCEPTANCE RATE: 102070/250000 (40.83 %)
# PARTIAL ACCEPTANCE RATES:
# 	NoisePerturbation(rayleigh): 14054/35643 (39.43%)
# 	ParamSpacePerturbation(param_space_name=voronoi):
# 		BirthPerturbation(voronoi): 132.00/36010.00 (0.37%)
# 		DeathPerturbation(voronoi): 131.00/35809.00 (0.37%)
# 		ParamPerturbation(voronoi.discretization): 19423.00/35706.00 (54.40%)
# 		ParamPerturbation(voronoi.vs): 68330.00/106832.00 (63.96%)
# Chain ID: 5
# TEMPERATURE: 1
# EXPLORED MODELS: 250000
# ACCEPTANCE RATE: 118405/250000 (47.36 %)
# PARTIAL ACCEPTANCE RATES:
# 	NoisePerturbation(rayleigh): 15794/35462 (44.54%)
# 	ParamSpacePerturbation(param_space_name=voronoi):
# 		BirthPerturbation(voronoi): 76.00/35864.00 (0.21%)
# 		DeathPerturbation(voronoi): 75.00/35730.00 (0.21%)
# 		ParamPerturbation(voronoi.discretization): 23152.00/35682.00 (64.88%)
# 		ParamPerturbation(voronoi.vs): 79308.00/107262.00 (73.94%)
# Chain ID: 6
# TEMPERATURE: 1
# EXPLORED MODELS: 250000
# ACCEPTANCE RATE: 113948/250000 (45.58 %)
# PARTIAL ACCEPTANCE RATES:
# 	NoisePerturbation(rayleigh): 14800/35599 (41.57%)
# 	ParamSpacePerturbation(param_space_name=voronoi):
# 		BirthPerturbation(voronoi): 10.00/35598.00 (0.03%)
# 		DeathPerturbation(voronoi): 8.00/35877.00 (0.02%)
# 		ParamPerturbation(voronoi.discretization): 21197.00/35621.00 (59.51%)
# 		ParamPerturbation(voronoi.vs): 77933.00/107305.00 (72.63%)
# Chain ID: 7
# TEMPERATURE: 1
# EXPLORED MODELS: 250000
# ACCEPTANCE RATE: 109423/250000 (43.77 %)
# PARTIAL ACCEPTANCE RATES:
# 	NoisePerturbation(rayleigh): 13198/35625 (37.05%)
# 	ParamSpacePerturbation(param_space_name=voronoi):
# 		BirthPerturbation(voronoi): 414.00/35367.00 (1.17%)
# 		DeathPerturbation(voronoi): 412.00/35837.00 (1.15%)
# 		ParamPerturbation(voronoi.discretization): 21699.00/35685.00 (60.81%)
# 		ParamPerturbation(voronoi.vs): 73700.00/107486.00 (68.57%)
# Chain ID: 8
# TEMPERATURE: 1
# EXPLORED MODELS: 250000
# ACCEPTANCE RATE: 112173/250000 (44.87 %)
# PARTIAL ACCEPTANCE RATES:
# 	NoisePerturbation(rayleigh): 15861/35586 (44.57%)
# 	ParamSpacePerturbation(param_space_name=voronoi):
# 		BirthPerturbation(voronoi): 60.00/35584.00 (0.17%)
# 		DeathPerturbation(voronoi): 59.00/35664.00 (0.17%)
# 		ParamPerturbation(voronoi.discretization): 21623.00/35820.00 (60.37%)
# 		ParamPerturbation(voronoi.vs): 74570.00/107346.00 (69.47%)
# Chain ID: 9
# TEMPERATURE: 1
# EXPLORED MODELS: 250000
# ACCEPTANCE RATE: 105742/250000 (42.30 %)
# PARTIAL ACCEPTANCE RATES:
# 	NoisePerturbation(rayleigh): 13955/35457 (39.36%)
# 	ParamSpacePerturbation(param_space_name=voronoi):
# 		BirthPerturbation(voronoi): 21.00/35894.00 (0.06%)
# 		DeathPerturbation(voronoi): 20.00/35707.00 (0.06%)
# 		ParamPerturbation(voronoi.discretization): 16960.00/35848.00 (47.31%)
# 		ParamPerturbation(voronoi.vs): 74786.00/107094.00 (69.83%)
# Chain ID: 10
# TEMPERATURE: 1
# EXPLORED MODELS: 250000
# ACCEPTANCE RATE: 105785/250000 (42.31 %)
# PARTIAL ACCEPTANCE RATES:
# 	NoisePerturbation(rayleigh): 14201/35847 (39.62%)
# 	ParamSpacePerturbation(param_space_name=voronoi):
# 		BirthPerturbation(voronoi): 98.00/35936.00 (0.27%)
# 		DeathPerturbation(voronoi): 97.00/35828.00 (0.27%)
# 		ParamPerturbation(voronoi.discretization): 20132.00/35506.00 (56.70%)
# 		ParamPerturbation(voronoi.vs): 71257.00/106883.00 (66.67%)
# Chain ID: 11
# TEMPERATURE: 1
# EXPLORED MODELS: 250000
# ACCEPTANCE RATE: 114494/250000 (45.80 %)
# PARTIAL ACCEPTANCE RATES:
# 	NoisePerturbation(rayleigh): 15407/35907 (42.91%)
# 	ParamSpacePerturbation(param_space_name=voronoi):
# 		BirthPerturbation(voronoi): 31.00/35658.00 (0.09%)
# 		DeathPerturbation(voronoi): 29.00/35640.00 (0.08%)
# 		ParamPerturbation(voronoi.discretization): 21689.00/35756.00 (60.66%)
# 		ParamPerturbation(voronoi.vs): 77338.00/107039.00 (72.25%)
# Elapsed time: 2.1358 minutes

# %%
importlib.reload(sf)

results = inversion.get_results(concatenate_chains=True)

#######################################
# GET RESULTS related to VS and DEPTH #
#######################################
sampled_voronoi_nuclei = results['voronoi.discretization']
sampled_thickness = [Voronoi1D.compute_cell_extents(n) for n in sampled_voronoi_nuclei]
sampled_vs = results['voronoi.vs']


step=.001 # increment by 1m
N = int(vmax / step) + 1
interp_depths = np.linspace(0, vmax, N)

statistics_vs = Voronoi1D.get_tessellation_statistics(sampled_thickness, sampled_vs, interp_depths, input_type='extents')

interf_bins=150
scale_vs=100 ## to scale the normalized Vs posterior range
depthpltmax=.3
fig, ax = sf.plot_vs_depth_posteriors(depth_prior, depthpltmax, vmax, vmin_prior, vmax_prior, vs_min, vs_max, vs_position, n_dimensions_min, n_dimensions_max,
    sampled_thickness, sampled_vs, statistics_vs, interp_depths, sampled_voronoi_nuclei, Voronoi1D, scale_vs, interf_bins, velocity_model)

ax[1].set_xlim(0,.6)

################################
# GET RESULTS related to NOISE #
################################
d_pred = np.array(results['rayleigh.dpred'])
percentiles = np.percentile(d_pred, (10, 90), axis=0)

noise_bins=20
fig, ax = sf.plot_data_noise_posterior(f_obs, d_obs, n_dimensions_min, n_dimensions_max, percentiles, results, target, noise_bins, noise_std_true);

ax[0].set_ylim(1.2,1.8)
ax[1].set_ylim(0,3e3)
ax[2].set_ylim(0,1)
# Out:
# /data2/somar/0_SOLVERS/BAYES-BAY/bayesbay_dev/lib/python3.9/site-packages/numpy/lib/_histograms_impl.py:895: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
# (0.0, 1.0)

# %%
importlib.reload(sf)
fig, ax = sf.plot_chains(inversion, Voronoi1D, interp_depths, depthpltmax, vmin, vmax, np.min(vs_min), np.max(vs_max), velocity_model)
